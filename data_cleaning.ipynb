# %%
import pandas as pd
import numpy as np
import os

# %%
df=pd.read_csv('./2015_16_course.csv')

# %%
print(df.shape)
# Out:
# (210015, 17)

# %%
df.head()
# Out:
#        id  mode_id  only_through_colleges  level_id  programme_id  \
# 0  949531        1                  False         1           157
# 1  949532        1                  False         3           111
# 2  949533        1                  False         6            82
# 3  949534        1                  False         4           180
# 4  957860        1                  False         8            39
#
#      discipline  broad_discipline_group  intake  no_of_applicants  \
# 0  Horticulture                       5     8.0               NaN
# 1  Horticulture                       5    51.0               NaN
# 2  Horticulture                       5    99.0               NaN
# 3   Horticuture                     107   187.0               NaN
# 4           Law                      52   144.0               NaN
#
#    duration_year  duration_month  type_id  examination_system_id  \
# 0              3               0        1                      2
# ...

# %%
df = df.drop(["only_through_colleges", "discipline", "broad_discipline_group","intake","no_of_applicants","duration_month","type_id","examination_system_id","approving_statutory_body_id","admission_criterion_id"], axis=1)

# %%
print(df.shape)
# Out:
# (210015, 7)

# %%
df.head()
# Out:
#        id  mode_id  level_id  programme_id  duration_year  \
# 0  949531        1         1           157              3
# 1  949532        1         3           111              2
# 2  949533        1         6            82              2
# 3  949534        1         4           180              4
# 4  957860        1         8            39              5
#
#   approving_university_id  broad_discipline_group_category_id
# 0                     NaN                                   1
# 1                     NaN                                   1
# 2                     NaN                                   1
# 3                     NaN                                  24
# 4                     NaN                                  15

# %%
ds=df.dropna()

# %%
print(df.shape)
print(ds.shape)
# Out:
# (210015, 7)
# (159173, 7)

# %%
ds.head()
# Out:
#             id  mode_id  level_id  programme_id  duration_year  \
# 34511  1071978        1         4            30              3
# 34512  1071977        1         4            12              3
# 34513  1071976        1         4            17              1
# 34514  1072024        1         4            17              2
# 34515   840507        1         4             6              3
#
#       approving_university_id  broad_discipline_group_category_id
# 34511                     525                                  24
# 34512                     525                                   3
# 34513                     525                                   6
# 34514                     212                                   6
# 34515                     550                                  28
